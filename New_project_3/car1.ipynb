# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
import time
import _sqlite3

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
from sqlalchemy import inspect,func

# %%
# path to sqlite
database_path = "Resources/car_data.sqlite"

# %%
# create engine that take the database
engine = create_engine(f"sqlite:///{database_path}")
engine
# Out:
# Engine(sqlite:///Resources/car_data.sqlite)

# %%
# Query All Records in the the Database
data = engine.execute("SELECT * FROM electric_car_data;")
for record in data:
    print(record)

# %%
# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine,reflect = True)

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %%
# create engine that take the database
engine = create_engine("sqlite:///{car_data.sqlite}")
conn = engine.connect()
conn

# %%
data = engine.execute("select * from electric_car_data")
for record in data:
    print(record)

# %%
engine
# Out:
# Engine(sqlite:///{database_path})

# %%
Base = automap_base()
# reflect the tables
Base.prepare(engine,reflect = True)

# %%
session = Session(engine)
session

# %%
# data = pd.read_csv("Resources/electric_car_data.csv")
# data
# Out:
#            Clean Alternative Fuel Vehicle Type  Vehicle_Id  Model Year  \
# 0               Battery Electric Vehicle (BEV)  5YJ3E1EA0J        2018
# 1       Plug-in Hybrid Electric Vehicle (PHEV)  1G1RB6S53H        2017
# 2       Plug-in Hybrid Electric Vehicle (PHEV)  5UXKT0C55J        2018
# 3               Battery Electric Vehicle (BEV)  7SAXCAE51P        2023
# 4               Battery Electric Vehicle (BEV)  KNDC4DLC1P        2023
# ...                                        ...         ...         ...
# 221427          Battery Electric Vehicle (BEV)  5YJSA1CG1D        2013
# 221428          Battery Electric Vehicle (BEV)  1N4AZ0CP2D        2013
# 221429          Battery Electric Vehicle (BEV)  1N4AZ0CP2D        2013
# 221430          Battery Electric Vehicle (BEV)  1N4AZ0CP7D        2013
# 221431          Battery Electric Vehicle (BEV)  1N4AZ0CP7D        2013
#
#              Make    Model  Electric Range New or Used Vehicle  Sale Price  \
# ...

# %%
# load csv file electric_vehicle_title
electric_vehicle_title_df = pd.read_csv("Resources/electric_vehicle_title_registration.csv")
electric_vehicle_title_df

# %%
# Clean DataFrame  Dropping columns unclear
drop_clumns = electric_vehicle_title_df.drop(columns=['Meets 2019 HB 2042 Sale Price/Value Requirement', 'Transportation Electrification Fee Paid', 'Hybrid Vehicle Electrification Fee Paid', 'Transportation Electrification Fee Paid'])
drop_clumns
# Out:
#            Clean Alternative Fuel Vehicle Type  VIN (1-10)  DOL Vehicle ID  \
# 0       Plug-in Hybrid Electric Vehicle (PHEV)  1G1RD6E47C       142240136
# 1       Plug-in Hybrid Electric Vehicle (PHEV)  1G1RD6E47C       142240136
# 2               Battery Electric Vehicle (BEV)  5YJ3E1EA0J       196972009
# 3               Battery Electric Vehicle (BEV)  5YJ3E1EA0J       196972009
# 4               Battery Electric Vehicle (BEV)  5YJ3E1EA0J       196972009
# ...                                        ...         ...             ...
# 740269          Battery Electric Vehicle (BEV)  1N4AZ0CP2D       121047804
# 740270          Battery Electric Vehicle (BEV)  1N4AZ0CP2D       121047804
# 740271          Battery Electric Vehicle (BEV)  1N4AZ0CP2D       121047804
# 740272          Battery Electric Vehicle (BEV)  1N4AZ0CP7D       144032402
# 740273          Battery Electric Vehicle (BEV)  1N4AZ0CP7D       144032402
#
# ...

# %%
# Clean DataFrame  Dropping columns unclear
clean_data1= drop_clumns.drop(columns=['Odometer Reading', 'Odometer Reading', '2019 HB 2042 Clean Alternative Fuel Vehicle (CAFV) Eligibility', 'Electric Vehicle Fee Paid','2015 HB 2778 Exemption Eligibility','Meets 2019 HB 2042 Electric Range Requirement','Meets 2019 HB 2042 Sale Date Requirement','2019 HB 2042: Battery Range Requirement'
,'2019 HB 2042: Purchase Date Requirement','2019 HB 2042: Sale Price/Value Requirement','2019 HB 2042: Purchase Date Requirement','2019 HB 2042: Sale Price/Value Requirement','2020 Census Tract','Legislative District','Electric Utility','County','Odometer Code','DOL Vehicle ID','Base MSRP','Odometer Reading', 'Odometer Reading', '2019 HB 2042 Clean Alternative Fuel Vehicle (CAFV) Eligibility', 'Electric Vehicle Fee Paid'])
clean_data1
# Out:
#            Clean Alternative Fuel Vehicle Type  VIN (1-10)  Model Year  \
# 0       Plug-in Hybrid Electric Vehicle (PHEV)  1G1RD6E47C        2012
# 1       Plug-in Hybrid Electric Vehicle (PHEV)  1G1RD6E47C        2012
# 2               Battery Electric Vehicle (BEV)  5YJ3E1EA0J        2018
# 3               Battery Electric Vehicle (BEV)  5YJ3E1EA0J        2018
# 4               Battery Electric Vehicle (BEV)  5YJ3E1EA0J        2018
# ...                                        ...         ...         ...
# 740269          Battery Electric Vehicle (BEV)  1N4AZ0CP2D        2013
# 740270          Battery Electric Vehicle (BEV)  1N4AZ0CP2D        2013
# 740271          Battery Electric Vehicle (BEV)  1N4AZ0CP2D        2013
# 740272          Battery Electric Vehicle (BEV)  1N4AZ0CP7D        2013
# 740273          Battery Electric Vehicle (BEV)  1N4AZ0CP7D        2013
#
#              Make    Model Vehicle Primary Use  Electric Range  \
# ...

# %%
# drop column 'Vehicle Primary Use
clean_data= clean_data1.drop(columns=['Vehicle Primary Use'])
clean_data
# Out:
#            Clean Alternative Fuel Vehicle Type  VIN (1-10)  Model Year  \
# 0       Plug-in Hybrid Electric Vehicle (PHEV)  1G1RD6E47C        2012
# 1       Plug-in Hybrid Electric Vehicle (PHEV)  1G1RD6E47C        2012
# 2               Battery Electric Vehicle (BEV)  5YJ3E1EA0J        2018
# 3               Battery Electric Vehicle (BEV)  5YJ3E1EA0J        2018
# 4               Battery Electric Vehicle (BEV)  5YJ3E1EA0J        2018
# ...                                        ...         ...         ...
# 740269          Battery Electric Vehicle (BEV)  1N4AZ0CP2D        2013
# 740270          Battery Electric Vehicle (BEV)  1N4AZ0CP2D        2013
# 740271          Battery Electric Vehicle (BEV)  1N4AZ0CP2D        2013
# 740272          Battery Electric Vehicle (BEV)  1N4AZ0CP7D        2013
# 740273          Battery Electric Vehicle (BEV)  1N4AZ0CP7D        2013
#
#              Make    Model  Electric Range New or Used Vehicle  Sale Price  \
# ...

# %%
# rename VIN 1-10 to Vehicle_Id
clean_data.rename(columns={'VIN (1-10)':'Vehicle_Id'}, inplace=True)

# %%
# rename VIN 1-10 to Vehicle_Id
clean_data.rename(columns=
{'VIN (1-10)':'Vehicle_Id'}, inplace=True)

# %%
# Pandas Dropna – How to drop missing values
# pandas.DataFrame.dropna(axis = 0, how =’any’, thresh = None, subset = None, inplace=False)
clean_car_data=clean_data.dropna(axis = 0, how ='any', thresh = None, subset = None, inplace=False)
clean_car_data
# Out:
#            Clean Alternative Fuel Vehicle Type  Vehicle_Id  Model Year  \
# 2               Battery Electric Vehicle (BEV)  5YJ3E1EA0J        2018
# 6       Plug-in Hybrid Electric Vehicle (PHEV)  1G1RB6S53H        2017
# 15      Plug-in Hybrid Electric Vehicle (PHEV)  5UXKT0C55J        2018
# 16              Battery Electric Vehicle (BEV)  7SAXCAE51P        2023
# 18              Battery Electric Vehicle (BEV)  KNDC4DLC1P        2023
# ...                                        ...         ...         ...
# 740264          Battery Electric Vehicle (BEV)  5YJSA1CG1D        2013
# 740269          Battery Electric Vehicle (BEV)  1N4AZ0CP2D        2013
# 740270          Battery Electric Vehicle (BEV)  1N4AZ0CP2D        2013
# 740272          Battery Electric Vehicle (BEV)  1N4AZ0CP7D        2013
# 740273          Battery Electric Vehicle (BEV)  1N4AZ0CP7D        2013
#
#              Make    Model  Electric Range New or Used Vehicle  Sale Price  \
# ...

# %%
unique_model =clean_car_data['Model Year'].unique()
unique_model
# Out:
# array([2018, 2017, 2023, 2019, 2016, 2020, 2021, 2013, 2015, 2014, 2022,
#        2011, 2012, 2010, 2024, 2008, 2000, 1999, 1998, 1993, 2003, 1997],
#       dtype=int64)

# %%
unique_mark = clean_car_data['Make'].unique()
unique_mark
# Out:
# array(['TESLA', 'CHEVROLET', 'BMW', 'KIA', 'VOLKSWAGEN', 'NISSAN',
#        'CHRYSLER', 'FORD', 'VOLVO', 'JAGUAR', 'HYUNDAI', 'PORSCHE',
#        'LINCOLN', 'RIVIAN', 'MINI', 'TOYOTA', 'AUDI', 'FIAT', 'SUBARU',
#        'SMART', 'JEEP', 'MERCEDES-BENZ', 'POLESTAR', 'CADILLAC', 'HONDA',
#        'LUCID', 'MITSUBISHI', 'LEXUS', 'FISKER', 'LAND ROVER', 'GENESIS',
#        'MAZDA', 'AZURE DYNAMICS', 'BUBBLE BUDDY', 'TH!NK',
#        'WHEEGO ELECTRIC CARS', 'DODGE', 'BENTLEY'], dtype=object)

# %%
# creat datafram from clean_care_data and save in csv file 
electric_car_data =pd.DataFrame(clean_car_data)
electric_car_data
# Out:
#            Clean Alternative Fuel Vehicle Type  Vehicle_Id  Model Year  \
# 2               Battery Electric Vehicle (BEV)  5YJ3E1EA0J        2018
# 6       Plug-in Hybrid Electric Vehicle (PHEV)  1G1RB6S53H        2017
# 15      Plug-in Hybrid Electric Vehicle (PHEV)  5UXKT0C55J        2018
# 16              Battery Electric Vehicle (BEV)  7SAXCAE51P        2023
# 18              Battery Electric Vehicle (BEV)  KNDC4DLC1P        2023
# ...                                        ...         ...         ...
# 740264          Battery Electric Vehicle (BEV)  5YJSA1CG1D        2013
# 740269          Battery Electric Vehicle (BEV)  1N4AZ0CP2D        2013
# 740270          Battery Electric Vehicle (BEV)  1N4AZ0CP2D        2013
# 740272          Battery Electric Vehicle (BEV)  1N4AZ0CP7D        2013
# 740273          Battery Electric Vehicle (BEV)  1N4AZ0CP7D        2013
#
#              Make    Model  Electric Range New or Used Vehicle  Sale Price  \
# ...

# %%
# aanlysis elcetric car sata model acourding our data is1993 1 
data_group_by_model_year =clean_car_data.groupby('Model Year').count()
data_group_by_model_year.head(3)

electric_df =pd.DataFrame(data_group_by_model_year)
electric_df
# Out:
#             Clean Alternative Fuel Vehicle Type  Vehicle_Id   Make  Model  \
# Model Year
# 1993                                          1           1      1      1
# 1997                                          1           1      1      1
# 1998                                          2           2      2      2
# 1999                                          5           5      5      5
# 2000                                         22          22     22     22
# 2003                                          2           2      2      2
# 2008                                         26          26     26     26
# 2010                                         93          93     93     93
# 2011                                       4047        4047   4047   4047
# 2012                                       7885        7885   7885   7885
# 2013                                      20386       20386  20386  20386
# ...

# %%
sale_price= clean_car_data['Sale Price'].unique()
sale_price
# Out:
# array([55000, 37570, 46495, ..., 94561, 40226,  3401], dtype=int64)

# %%
clean_car_data.rpow
# Out:
# <bound method _arith_method_FRAME.<locals>.f of            Clean Alternative Fuel Vehicle Type  Vehicle_Id  Model Year  \
# 2               Battery Electric Vehicle (BEV)  5YJ3E1EA0J        2018
# 6       Plug-in Hybrid Electric Vehicle (PHEV)  1G1RB6S53H        2017
# 15      Plug-in Hybrid Electric Vehicle (PHEV)  5UXKT0C55J        2018
# 16              Battery Electric Vehicle (BEV)  7SAXCAE51P        2023
# 18              Battery Electric Vehicle (BEV)  KNDC4DLC1P        2023
# ...                                        ...         ...         ...
# 740264          Battery Electric Vehicle (BEV)  5YJSA1CG1D        2013
# 740269          Battery Electric Vehicle (BEV)  1N4AZ0CP2D        2013
# 740270          Battery Electric Vehicle (BEV)  1N4AZ0CP2D        2013
# 740272          Battery Electric Vehicle (BEV)  1N4AZ0CP7D        2013
# 740273          Battery Electric Vehicle (BEV)  1N4AZ0CP7D        2013
#
# ...

# %%
# # Pandas Dropna – How to drop missing values?

# # Syntax: pandas.DataFrame.dropna(axis = 0, how =’any’, thresh = None, subset = None, inplace=False)
# electric_vehicle=electric_car.dropna(axis = 0, how ='any', thresh = None, subset = None, inplace=False)
# electric_vehicle

# %%
# Reference multiple columns within a Data electric_car to analysisthe data car make in where cities been used 

car_city_data=electric_car_data[["City","Make","Model Year","DOL Transaction Date","Transaction Type","New or Used Vehicle"]].head()
car_city_data
# Out:
#          City       Make  Model Year DOL Transaction Date Transaction Type  \
# 2     SEATTLE      TESLA        2018         June 06 2018   Original Title
# 6      RENTON  CHEVROLET        2017     February 22 2017   Original Title
# 15     RENTON        BMW        2018     February 23 2021   Transfer Title
# 16  VANCOUVER      TESLA        2023     November 03 2022   Original Title
# 18    SEATTLE        KIA        2023          May 02 2023   Original Title
#
#    New or Used Vehicle
# 2                  New
# 6                  New
# 15                Used
# 16                 New
# 18                 New

# %%
# create dataFram car_make_data to sorle by city make,model years and newor use 
car_make_data=electric_car_data[["Make","Model Year","New or Used Vehicle","City",]]
car_make_data
# Out:
#              Make  Model Year New or Used Vehicle       City
# 2           TESLA        2018                 New    SEATTLE
# 6       CHEVROLET        2017                 New     RENTON
# 15            BMW        2018                Used     RENTON
# 16          TESLA        2023                 New  VANCOUVER
# 18            KIA        2023                 New    SEATTLE
# ...           ...         ...                 ...        ...
# 740264      TESLA        2013                 New    SEATTLE
# 740269     NISSAN        2013                Used   LYNNWOOD
# 740270     NISSAN        2013                Used   LYNNWOOD
# 740272     NISSAN        2013                 New    PACIFIC
# 740273     NISSAN        2013                 New    PACIFIC
#
# [221432 rows x 4 columns]

# %%
sale_date= clean_car_data['Sale Date'].value_counts()
sale_date

# %%
# Generate a summary statistics table of mean, median, 
# Use groupby and summary statistical methods to calculate the following properties of each sale 


mean = clean_car_data['Sale Price'].groupby(clean_car_data ['Make']).mean()
median = clean_car_data['Sale Price'].groupby(clean_car_data ['Make']).median()
max = clean_car_data['Sale Price'].groupby(clean_car_data ['Make']).max()
min = clean_car_data['Sale Price'].groupby(clean_car_data['Make']).min()

# %%
summary_sale_data = pd.DataFrame({
    'car sale mean': mean,
    'car sale median': median,
    'car sale max': max,
    'car sale min': min
})

summary_sale_data
# Out:
#                       car sale mean  car sale median  car sale max  \
# Make
# AUDI                   54149.662324          59364.0        189390
# AZURE DYNAMICS          3399.083333            750.0         13750
# BENTLEY               227158.333333         236000.0        277475
# BMW                    36133.926524          29999.0        474160
# BUBBLE BUDDY            6778.000000           6778.0          6778
# CADILLAC               21246.753205          18306.5        499956
# CHEVROLET              18488.895510          17308.0        170000
# CHRYSLER               43516.494935          46021.0        121918
# DODGE                      0.000000              0.0             0
# FIAT                    8813.458280           8995.0        940325
# FISKER                 12282.077922              0.0        110000
# FORD                   20989.376710          12000.0        349990
# GENESIS                70450.209677          70220.0         81710
# ...

# %%
#  summary_sale save transfer to csv file
electric_car_data.to_csv("Resources/electric_car_data.csv", index=False)
electric_car_data
# Out:
#            Clean Alternative Fuel Vehicle Type  Vehicle_Id  Model Year  \
# 2               Battery Electric Vehicle (BEV)  5YJ3E1EA0J        2018
# 6       Plug-in Hybrid Electric Vehicle (PHEV)  1G1RB6S53H        2017
# 15      Plug-in Hybrid Electric Vehicle (PHEV)  5UXKT0C55J        2018
# 16              Battery Electric Vehicle (BEV)  7SAXCAE51P        2023
# 18              Battery Electric Vehicle (BEV)  KNDC4DLC1P        2023
# ...                                        ...         ...         ...
# 740264          Battery Electric Vehicle (BEV)  5YJSA1CG1D        2013
# 740269          Battery Electric Vehicle (BEV)  1N4AZ0CP2D        2013
# 740270          Battery Electric Vehicle (BEV)  1N4AZ0CP2D        2013
# 740272          Battery Electric Vehicle (BEV)  1N4AZ0CP7D        2013
# 740273          Battery Electric Vehicle (BEV)  1N4AZ0CP7D        2013
#
#              Make    Model  Electric Range New or Used Vehicle  Sale Price  \
# ...

# %%
#  summary_sale save transfer to csv file
summary_sale_data.to_csv("Resources/summary_sale_data.csv", index=False)
summary_sale_data
# Out:
#                       car sale mean  car sale median  car sale max  \
# Make
# AUDI                   54149.662324          59364.0        189390
# AZURE DYNAMICS          3399.083333            750.0         13750
# BENTLEY               227158.333333         236000.0        277475
# BMW                    36133.926524          29999.0        474160
# BUBBLE BUDDY            6778.000000           6778.0          6778
# CADILLAC               21246.753205          18306.5        499956
# CHEVROLET              18488.895510          17308.0        170000
# CHRYSLER               43516.494935          46021.0        121918
# DODGE                      0.000000              0.0             0
# FIAT                    8813.458280           8995.0        940325
# FISKER                 12282.077922              0.0        110000
# FORD                   20989.376710          12000.0        349990
# GENESIS                70450.209677          70220.0         81710
# ...

# %%
# export electric_car as CSV files.
electric_car_data.to_csv("Resources/electric_car_data.csv", index=False)
electric_car_data
# Out:
#            Clean Alternative Fuel Vehicle Type  Vehicle_Id  Model Year  \
# 2               Battery Electric Vehicle (BEV)  5YJ3E1EA0J        2018
# 6       Plug-in Hybrid Electric Vehicle (PHEV)  1G1RB6S53H        2017
# 15      Plug-in Hybrid Electric Vehicle (PHEV)  5UXKT0C55J        2018
# 16              Battery Electric Vehicle (BEV)  7SAXCAE51P        2023
# 18              Battery Electric Vehicle (BEV)  KNDC4DLC1P        2023
# ...                                        ...         ...         ...
# 740264          Battery Electric Vehicle (BEV)  5YJSA1CG1D        2013
# 740269          Battery Electric Vehicle (BEV)  1N4AZ0CP2D        2013
# 740270          Battery Electric Vehicle (BEV)  1N4AZ0CP2D        2013
# 740272          Battery Electric Vehicle (BEV)  1N4AZ0CP7D        2013
# 740273          Battery Electric Vehicle (BEV)  1N4AZ0CP7D        2013
#
#              Make    Model  Electric Range New or Used Vehicle  Sale Price  \
# ...

# %%
count_row = electric_car.shape[0]
count_row
# Out:
# 221021

# %%
# export car_city as CSV files.
car_city_data.to_csv("Resources/city_car_data.csv", index=False)
car_city_data
# Out:
#          City       Make  Model Year DOL Transaction Date Transaction Type  \
# 2     SEATTLE      TESLA        2018         June 06 2018   Original Title
# 6      RENTON  CHEVROLET        2017     February 22 2017   Original Title
# 15     RENTON        BMW        2018     February 23 2021   Transfer Title
# 16  VANCOUVER      TESLA        2023     November 03 2022   Original Title
# 18    SEATTLE        KIA        2023          May 02 2023   Original Title
#
#    New or Used Vehicle
# 2                  New
# 6                  New
# 15                Used
# 16                 New
# 18                 New

# %%
# export car_make as CSV files.
car_make_data.to_csv("Resources/car_make.csv", index=False)
car_make_data
# Out:
#              Make  Model Year New or Used Vehicle       City
# 2           TESLA        2018                 New    SEATTLE
# 6       CHEVROLET        2017                 New     RENTON
# 15            BMW        2018                Used     RENTON
# 16          TESLA        2023                 New  VANCOUVER
# 18            KIA        2023                 New    SEATTLE
# ...           ...         ...                 ...        ...
# 740264      TESLA        2013                 New    SEATTLE
# 740269     NISSAN        2013                Used   LYNNWOOD
# 740270     NISSAN        2013                Used   LYNNWOOD
# 740272     NISSAN        2013                 New    PACIFIC
# 740273     NISSAN        2013                 New    PACIFIC
#
# [221432 rows x 4 columns]

# %%
# Export datafram  to json df.to_json(path, orient='records')
electric_car_data.to_json('electric_car_data', orient='records')

# %%
# Export datafram  to json df.to_json(path, orient='records')
car_city_data.to_json('car_city_data.json', orient='records')

# %%
# Export datafram  to json df.to_json(path, orient='records')
car_make_data.to_json('car_make_data.json', orient='records')

# %%
# Export datafram  to json df.to_json(path, orient='records')
summary_sale_data.to_json('car_sale_data.json', orient='records')
